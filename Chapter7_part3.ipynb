# %% [markdown]
# # **BÀI TẬP CHƯƠNG 7**

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 1</b></p>
#
# - Tải bộ dữ liệu `BACE.csv` vào một dataframe. Bộ dữ liệu này bao gồm 12 cột thông tin của phân tử, và cột cuối cùng là `pIC50` đặc trưng cho khả năng ức chế β-secretase ở người của phân tử.
#
# - Tìm hiểu về 12 cột đầu vào (input) dự trên tiêu đề của cột, cho biết cột đó biểu thị thông tin gì?
#
# - Xác định các tham số đặc trưng về sự tập trung vào phân bố cho tất cả các cột của bộ dữ liệu trên (trình bày dưới dạng rõ ràng, dễ nhìn và dễ đánh giá): số trội, khoảng giá trị, trung bình, độ lệch chuẩn, hệ số biến thiên.
#
# - Biểu thị các đặc trưng này bằng các đồ thị thích hợp.

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 2</b></p>
#
# - Phân tích ảnh hưởng của các cột thông tin đầu vào có ảnh hưởng tới đầu ra (`pIC50`) hay không bằng phương pháp phân tích phương sai? (Mức ý nghĩa: $\alpha = 0.05$). Trình bày kết quả phân tích dưới dạng rõ ràng, dễ nhìn và dễ đánh giá.
#
# - Nếu xác định có yếu tố không ảnh hưởng đến đầu ra, loại yếu tố đó ra khỏi dataframe

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 3</b></p>
#
# Thực hiện xử lý dữ liệu đầu vào:
# - Từ dataframe đã loại bỏ các yếu tố không ảnh hưởng, tách các cột đầu vào thành biến `x` và cột đầu ra thành biến `y` (`x` và `y` là các numpy array 2 chiều).
# - Thay đổi khoảng giá trị của tất cả các cột để chúng nằm trong khoảng `(0, 1)` sử dụng 2 `MinMaxScaler` cho input và output.
# - Thực hiện tách dữ liệu thành 2 bộ `train` và `test` (lưu trong 4 biến `x_train_scaled`, `x_test_scaled`, `y_train_scaled`, `y_test_scaled`).

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 4</b></p>
#
# Xây dựng mô hình học máy:
# - Xây dựng ít nhất 3 mô hình học máy tự chọn (không dùng mô hình học sâu), huấn luyện chúng dựa trên bộ `train` đã tách ra.
# - Đánh giá kết quả của các mô hình bằng các thông số đánh giá hồi quy với bộ `test`.
# - Biểu diễn bằng đồ thị scatter plot giữa giá trị dự đoán và giá trị thực.
# - Dựa và kết quả, chọn ra mô hình tốt nhất.

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 5</b></p>
#
# Xây dựng mô hình học sâu:
# - Xây dựng ít nhất 1 mô hình học sâu MLP có cấu trúc tự chọn (ít nhất 2 lớp) bằng `PyTorch`, huấn luyện dựa trên bộ `train` đã tách ra.
# - Đánh giá kết quả của các mô hình bằng các thông số đánh giá hồi quy với bộ `test`.
# - Biểu diễn bằng đồ thị scatter plot giữa giá trị dự đoán và giá trị thực.
# - Dựa và kết quả, so sánh mô hình này với các mô hình học máy ở trên.

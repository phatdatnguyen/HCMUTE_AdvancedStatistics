# %% [markdown]
# # **BÀI TẬP CHƯƠNG 4**

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 1</b></p>
#
# Khảo sát điều kiện tối ưu để phân hủy KMnO₄ phụ thuộc vào 2 yếu tố: nhiệt độ $X_1$ (°C) và lượng chất xúc tác $X_2$ (mg/L). Ma trận thực nghiệm được cho ở bảng sau:
#
# | STT | $X_1$ | $X_2$ | Hiệu suất (%) |
# |-----|---------|---------|---------------|
# | 1   | -1      | -1      | 95            |
# | 2   | +1      | -1      | 89            |
# | 3   | -1      | +1      | 80            |
# | 4   | +1      | +1      | 72            |
# | 5   | 0       | 0       | 85            |
# | 6   | 0       | 0       | 86            |
# | 7   | 0       | 0       | 86.5          |
#
# a) Tìm phương trình hồi quy mô tả thực nghiệm trên với $p = 95\%$.
#
# b) Đánh giá tính phù hợp của phương trình thu được.

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 2</b></p>
#
# Tiến hành phản ứng phân hủy $KClO_3$. Khảo sát hiệu suất phân hủy $KClO_3$ dựa theo mô hình hóa thực nghiệm bậc 1 rút gọn với hệ thức phát sinh $X_4 = X_1X_2X_3$. Các yếu tố ảnh hưởng tới hiệu suất phân hủy:
#
# - $Z_1$: thời gian phản ứng (giây);
# - $Z_2$: khối lượng ban đầu của $KClO_3$ (gam);
# - $Z_3$: khối lượng xúc tác $MnO_2$ (gam);
# - $Z_4$: nhiệt độ (°C).
#
# Dữ liệu thực nghiệm:
#
# | STT | $Z_1$| $Z_2$ | $Z_3$ | $Z_4$ | $Y$ |
# |-----|---------|---------|---------|---------|-------|
# | 1   | 60      | 16      | 0.8     | 80      | 44    |
# | 2   | 100     | 16      | 0.8     | 120     | 70    |
# | 3   | 60      | 24      | 0.8     | 120     | 39    |
# | 4   | 100     | 24      | 0.8     | 80      | 98    |
# | 5   | 60      | 16      | 1.6     | 120     | 11    |
# | 6   | 100     | 16      | 1.6     | 80      | 65    |
# | 7   | 60      | 24      | 1.6     | 80      | 51    |
# | 8   | 100     | 24      | 1.6     | 120     | 77    |
# | 9   | 80      | 20      | 1.2     | 100     | 56    |
# | 10  | 80      | 20      | 1.2     | 100     | 58    |
# | 11  | 80      | 20      | 1.2     | 100     | 57    |
#
# a) Tìm phương trình hồi quy mô tả thực nghiệm trên với $p = 99\%$.
#
# b) Đánh giá tính phù hợp của phương trình thu được.

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 3</b></p>
#
# Kiểm tra quá trình tách thủy ngân từ các hợp chất có tính kiềm. Hàm lượng $Hg$ sau khi được chiết ra có thể được đo bằng phương pháp phổ hấp thụ nguyên tử với độ chính xác $10^{-6}\%$. Các nhân tố ảnh hưởng:
#
# - $X_1$: tốc độ quay (phút⁻¹);
# - $X_2$: nhiệt độ của dung dịch (°C);
# - $X_3$: thời gian lưu của dung dịch (phút).
#
# Điều kiện thực nghiệm:
#
# | Nhân tố | $X_1$ | $X_2$ | $X_3$ |
# |---------|---------|---------|---------|
# | Mức gốc | 2500    | 100     | 45      |
# | Biến thiên | 1500 | 30      | 15      |
#
# Ma trận thực nghiệm:
#
# | STT | $X_1$ | $X_2$ | $X_3$ | $y_1$ ($10^{-4}$) | $y_2$ ($10^{-4}$) | $y_3$ ($10^{-4}$) |
# |-----|---------|---------|---------|-----------------------|-----------------------|-----------------------|
# | 1   | -1      | -1      | -1      | 6.64                 | 6.26                 | 6.17                 |
# | 2   | +1      | -1      | -1      | 3.74                 | 3.34                 | 3.65                 |
# | 3   | -1      | +1      | -1      | 3.01                 | 2.59                 | 2.80                 |
# | 4   | +1      | +1      | -1      | 2.90                 | 2.50                 | 2.50                 |
# | 5   | -1      | -1      | +1      | 3.42                 | 3.02                 | 3.52                 |
# | 6   | +1      | -1      | +1      | 3.07                 | 2.65                 | 2.83                 |
# | 7   | -1      | +1      | +1      | 1.34                 | 1.05                 | 1.27                 |
# | 8   | +1      | +1      | +1      | 1.09                 | 0.81                 | 0.99                 |
#
# a) Tìm phương trình hồi quy mô tả thực nghiệm trên với $p = 95\%$.
#
# b) Đánh giá tính phù hợp của phương trình thu được.

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 4</b></p>
#
# Quá trình kết dính của các chất nền dựa trên sự chiết thuỷ ngân từ dung dịch muối acid bằng nhôm kim loại. Sự nghiên cứu động học của phản ứng hóa học này chỉ ra quá trình này bị ảnh hưởng bởi các yếu tố:
# - Nhiệt độ của dung dịch, $X_1$ (°C)
# - Tốc độ chảy của dung dịch trong bình phản ứng, $X_2$ (mL/min)
# - Khối lượng của nhôm, $X_3$ (g)
#
# Kết quả của quá trình được xác định bằng nồng độ của thuỷ ngân trong dung dịch sau khi tinh chế (y).
#
# Tiến hành quy hoạch thực nghiệm thu được kết quả như sau:
#
# | Các yếu tố | Các mức             |
# |------------|---------------------|
# |            | Mức trên (+) | Mức cơ sở (0) | Mức dưới (-1) |
# | $X_1$  | 90          | 80          | 70          |
# | $X_2$  | 1050        | 750         | 450         |
# | $X_3$  | 14.66       | 12.66       | 10.66       |
#
# Ma trận bậc hai tâm xoay và kết quả thí nghiệm:
#
# | STT | $X_0$ | $X_1$ | $X_2$ | $X_3$ | $y$   |
# |-----|-----------|-----------|-----------|-----------|-----------|
# | 1   | +1        | -1        | -1        | -1        | 0.4271    |
# | 2   | +1        | +1        | -1        | -1        | 0.2761    |
# | 3   | +1        | -1        | +1        | -1        | 0.7045    |
# | 4   | +1        | +1        | +1        | -1        | 0.3855    |
# | 5   | +1        | -1        | -1        | +1        | 0.1034    |
# | 6   | +1        | +1        | -1        | +1        | 0.0956    |
# | 7   | +1        | -1        | +1        | +1        | 0.294     |
# | 8   | +1        | +1        | +1        | +1        | 0.108     |
# | 9   | +1        | -1.682    | 0         | 0         | 0.3464    |
# | 10  | +1        | 1.682     | 0         | 0         | 0.0783    |
# | 11  | +1        | 0         | -1.682    | 0         | 0.0714    |
# | 12  | +1        | 0         | 1.682     | 0         | 0.3321    |
# | 13  | +1        | 0         | 0         | -1.682    | 0.7048    |
# | 14  | +1        | 0         | 0         | 1.682     | 0.2094    |
# | 15  | +1        | 0         | 0         | 0         | 0.1224    |
# | 16  | +1        | 0         | 0         | 0         | 0.1382    |
# | 17  | +1        | 0         | 0         | 0         | 0.1204    |
# | 18  | +1        | 0         | 0         | 0         | 0.0943    |
# | 19  | +1        | 0         | 0         | 0         | 0.0698    |
# | 20  | +1        | 0         | 0         | 0         | 0.1135    |
#
# Xây dựng phương trình hồi quy và đánh giá tính phù hợp của mô hình thu được với $\alpha = 0.05$.

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 5</b></p>
#
# Tiến hành quá trình điều chế một dược phẩm trong điều kiện tối ưu hóa. Hiệu suất phản ứng phụ thuộc vào:
# - $X_1$: nồng độ sắt (g/L)
# - $X_2$: thời gian oxi hóa (phút)
# - $X_3$: nồng độ acid (%)
#
# Tiến hành quy hoạch thực nghiệm thu được kết quả:
#
# | Tên         | $X_1$ | $X_2$ | $X_3$ |
# |-------------|-----------|-----------|-----------|
# | Mức thấp    | 30        | 15        | 14        |
# | Mức cơ sở   | 45        | 37.5      | 27        |
# | Mức cao     | 60        | 60        | 40        |
#
# | STT | $X_1$   | $X_2$   | $X_3$   | $y$   |
# |-----|-------------|-------------|-------------|-----------|
# | 1   | -1          | -1          | -1          | 47.6      |
# | 2   | +1          | -1          | -1          | 68.6      |
# | 3   | -1          | +1          | -1          | 51.8      |
# | 4   | +1          | +1          | -1          | 91.0      |
# | 5   | -1          | -1          | +1          | 29.1      |
# | 6   | +1          | -1          | +1          | 66.0      |
# | 7   | -1          | +1          | +1          | 34.4      |
# | 8   | +1          | +1          | +1          | 74.5      |
# | 9   | -1.2154     | 0           | 0           | 41.7      |
# | 10  | +1.2154     | 0           | 0           | 95.4      |
# | 11  | 0           | -1.2154     | 0           | 42.4      |
# | 12  | 0           | +1.2154     | 0           | 70.0      |
# | 13  | 0           | 0           | -1.2154     | 52.3      |
# | 14  | 0           | 0           | +1.2154     | 45.6      |
# | 15  | 0           | 0           | 0           | 61.8      |
#
# Phương sai lặp lại được xác định theo 4 thí nghiệm tại điểm tối ưu ($y_1 = 51.5$; $y_2 = 45.6$; $y_3 = 54.5$; $y_4 = 61.8$).
#
# Xây dựng phương trình hồi quy bậc hai tâm trực giao và đánh giá tính có nghĩa của mô hình hồi quy tìm được trong trường hợp $\alpha = 0.05$ và $\alpha = 0.01$.

# %% [markdown]
# <p style="background-color: lightgreen; text-align: center; font-size: 18px; color: red; padding: 5px; border-radius: 10px;"><b>Bài tập 6</b></p>
#
# Hiệu suất ($y$) của quá trình khâu mạch nhựa epoxi bằng chất TAS, độ bền va đập của vật liệu (N/cm²) phụ thuộc vào các yếu tố sau:
# - Hàm lượng TAS (%), $X_1$
# - Nhiệt độ phản ứng (°C), $X_2$
#
# Kết quả tiến hành thí nghiệm được cho dưới đây:
#
# | Nhân tố | Mức thấp | Mức cao |
# |---------|----------|---------|
# | $X_1$  | 50       | 70      |
# | $X_2$  | 110      | 140     |
#
# | STT | $X_1$      | $X_2$      | $y$       |
# |-----|------------|------------|-----------|
# | 1   | -1         | -1         | 79        |
# | 2   | +1         | -1         | 85.1      |
# | 3   | -1         | +1         | 91        |
# | 4   | +1         | +1         | 87.1      |
# | 5   | -1.414     | 0          | 90        |
# | 6   | +1.414     | 0          | 85.6      |
# | 7   | 0          | -1.414     | 77        |
# | 8   | 0          | +1.414     | 84.5      |
# | 9   | 0          | 0          | 83.7      |
# | 10  | 0          | 0          | 85.1      |
# | 11  | 0          | 0          | 85.8      |
# | 12  | 0          | 0          | 83.9      |
# | 13  | 0          | 0          | 86.3      |
#
# a) Xác định các hệ số hồi quy trong phương trình hồi quy phù hợp.
# b) Đánh giá tính phù hợp của các hệ số hồi quy và mô hình hồi quy tìm được với $\alpha = 0.05$.
